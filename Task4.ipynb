# %% [markdown]
# # **Name: Kanishka Singh**
#
# **Data Science & Business Analytics Tasks**
#
# **Intern at GRIP Spark foundation.**
#
#
# **Task Number: Intermediate level 1**
#
#
# **Topic: Exploratory Data Analysis - Terrorism**

# %% [markdown]
# # **EDA on Terrorism**

# %% [markdown]
# In this task, we will conduct Exploratory Data Analysis on a terrorist dataset to determine the hot zone of terrorism. Exploratory data analysis is just analysing the supplied data to discover trends, patterns, and make certain assumptions. There are various attributes in this dataset, including nations, states, regions, gang names, weapon kinds, target categories, years, months, days, and many more.

# %% [markdown]
# # **Importing Libraries**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# # **Importing the datasets**

# %%
df=pd.read_csv("/content/drive/MyDrive/globalterrorismdb_0718dist.csv", encoding="latin1")
# Out:
# <ipython-input-4-583c7ca192c1>:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/content/drive/MyDrive/globalterrorismdb_0718dist.csv", encoding="latin1")

# %% [markdown]
# # **Printing the values**

# %%
df.head(5)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.tail(5)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
for i in df.columns:
    print(i,end=", ")
# Out:
# eventid, iyear, imonth, iday, approxdate, extended, resolution, country, country_txt, region, region_txt, provstate, city, latitude, longitude, specificity, vicinity, location, summary, crit1, crit2, crit3, doubtterr, alternative, alternative_txt, multiple, success, suicide, attacktype1, attacktype1_txt, attacktype2, attacktype2_txt, attacktype3, attacktype3_txt, targtype1, targtype1_txt, targsubtype1, targsubtype1_txt, corp1, target1, natlty1, natlty1_txt, targtype2, targtype2_txt, targsubtype2, targsubtype2_txt, corp2, target2, natlty2, natlty2_txt, targtype3, targtype3_txt, targsubtype3, targsubtype3_txt, corp3, target3, natlty3, natlty3_txt, gname, gsubname, gname2, gsubname2, gname3, gsubname3, motive, guncertain1, guncertain2, guncertain3, individual, nperps, nperpcap, claimed, claimmode, claimmode_txt, claim2, claimmode2, claimmode2_txt, claim3, claimmode3, claimmode3_txt, compclaim, weaptype1, weaptype1_txt, weapsubtype1, weapsubtype1_txt, weaptype2, weaptype2_txt, weapsubtyp
# ...

# %% [markdown]
# # **Data Cleaning**

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
# ...

# %%
df=df[["iyear","imonth","iday","country_txt","region_txt","provstate","city",
       "latitude","longitude","location","summary","attacktype1_txt","targtype1_txt",
       "gname","motive","weaptype1_txt","nkill","nwound","addnotes"]]
df.head()
# Out:
#    iyear  imonth  iday         country_txt                   region_txt  \
# 0   1970       7     2  Dominican Republic  Central America & Caribbean
# 1   1970       0     0              Mexico                North America
# 2   1970       1     0         Philippines               Southeast Asia
# 3   1970       1     0              Greece               Western Europe
# 4   1970       1     0               Japan                    East Asia
#
#   provstate           city   latitude   longitude location summary  \
# 0       NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1   Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2    Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3    Attica         Athens  37.997490   23.762728      NaN     NaN
# 4   Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                   attacktype1_txt                targtype1_txt  \
# ...

# %%
df.rename(columns={"iyear":"Year","imonth":"Month","iday":"Day","country_txt":"Country",
                   "region_txt":"Region","provstate":"State","city":"City",
                   "latitude":"Latitude","longitude":"Longitude","location":"Location",
                   "summary":"Summary","attacktype1_txt":"Attack Type","targtype1_txt":"Target Type",
                   "gname":"Group Name","motive":"Motive","weaptype1_txt":"Weapon Type",
                   "nkill":"Killed","nwound":"Wounded","addnotes":"Add Notes"},inplace=True)
# Out:
# <ipython-input-16-505c5db361f4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"iyear":"Year","imonth":"Month","iday":"Day","country_txt":"Country",

# %%
df.head(5)
# Out:
#    Year  Month  Day             Country                       Region    State  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean      NaN
# 1  1970      0    0              Mexico                North America  Federal
# 2  1970      1    0         Philippines               Southeast Asia   Tarlac
# 3  1970      1    0              Greece               Western Europe   Attica
# 4  1970      1    0               Japan                    East Asia  Fukouka
#
#             City   Latitude   Longitude Location Summary  \
# 0  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1    Mexico city  19.371887  -99.086624      NaN     NaN
# 2        Unknown  15.478598  120.599741      NaN     NaN
# 3         Athens  37.997490   23.762728      NaN     NaN
# 4        Fukouka  33.580412  130.396361      NaN     NaN
#
#                       Attack Type                  Target Type  \
# 0                   Assassination  Private Citizens & Property
# ...

# %%
df.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded
# count  1.771340e+05  171378.000000  165380.000000
# mean  -4.586957e+02       2.403272       3.167668
# std    2.047790e+05      11.545741      35.949392
# min   -8.618590e+07       0.000000       0.000000
# 25%    4.545640e+00       0.000000       0.000000
# 50%    4.324651e+01       0.000000       0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   Region       181691 non-null  object
#  5   State        181270 non-null  object
#  6   City         181257 non-null  object
#  7   Latitude     177135 non-null  float64
#  8   Longitude    177134 non-null  float64
#  9   Location     55495 non-null   object
#  10  Summary      115562 non-null  object
#  11  Attack Type  181691 non-null  object
#  12  Target Type  181691 non-null  object
#  13  Group Name   181691 non-null  object
#  14  Motive       50561 non-null   object
#  15  Weapon Type  181691 non-null  object
#  16  Killed       171378 non-null  float64
#  17  Wounded      165380 non-null  float64
# ...

# %%
df.shape
# Out:
# (181691, 19)

# %%
df.isnull().sum()
# Out:
# Year                0
# Month               0
# Day                 0
# Country             0
# Region              0
# State             421
# City              434
# Latitude         4556
# Longitude        4557
# Location       126196
# Summary         66129
# Attack Type         0
# Target Type         0
# Group Name          0
# Motive         131130
# Weapon Type         0
# Killed          10313
# Wounded         16311
# Add Notes      153402
# dtype: int64

# %%
df["Killed"]=df["Killed"].fillna(0)
df["Wounded"]=df["Wounded"].fillna(0)
df["Casualty"]=df["Killed"]+df["Wounded"]
# Out:
# <ipython-input-24-a027e751f953>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Killed"]=df["Killed"].fillna(0)
# <ipython-input-24-a027e751f953>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Wounded"]=df["Wounded"].fillna(0)
# <ipython-input-24-a027e751f953>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded       Casualty
# count  1.771340e+05  181691.000000  181691.000000  181691.000000
# mean  -4.586957e+02       2.266860       2.883296       5.150156
# std    2.047790e+05      11.227057      34.309747      40.555416
# min   -8.618590e+07       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# # **Year wise Attacks :**

# %%
attacks=df["Year"].value_counts(dropna=False).sort_index().to_frame().reset_index().rename(columns={"index":"Year","Year":"Attacks"}).set_index("Year")
attacks.head()
# Out:
#       Attacks
# Year
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581

# %%
attacks.plot(kind="bar",color="red",figsize=(20,5),fontsize=13)
plt.title("Timeline of Attacks",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.show()

# %%
yc=df[["Year","Casualty"]].groupby("Year").sum()
yc.head()
# Out:
#       Casualty
# Year
# 1970     386.0
# 1971     255.0
# 1972     975.0
# 1973     865.0
# 1974    1404.0

# %%
yc.plot(kind="bar",color="red",figsize=(20,5))
plt.title("Year wise Casualties",fontsize=13)
plt.xlabel("Years",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %%
yk=df[["Year","Killed"]].groupby("Year").sum()
yk.head()
# Out:
#       Killed
# Year
# 1970   174.0
# 1971   173.0
# 1972   566.0
# 1973   370.0
# 1974   539.0

# %%
yw=df[["Year","Wounded"]].groupby("Year").sum()
yw.head()
# Out:
#       Wounded
# Year
# 1970    212.0
# 1971     82.0
# 1972    409.0
# 1973    495.0
# 1974    865.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(2,1,1)
ax1=fig.add_subplot(2,1,2)

#Killed
yk.plot(kind="bar",color="red",figsize=(20,9),ax=ax0)
ax0.set_title("People Killed in each Year")
ax0.set_xlabel("Years")
ax0.set_ylabel("Number of People Killed") 

#Wounded
yw.plot(kind="bar",color="red",figsize=(20,9),ax=ax1)
ax1.set_title("People Wounded in each Year")
ax1.set_xlabel("Years")
ax1.set_ylabel("Number of People Wounded")

plt.show()

# %% [markdown]
# 1.       **Year wise Attacks :**
#
#
# 1.  **Attacks**
#
# (a) Most number of attacks: 16903 in 2014
#
# (b) Least number of attacks: 471 in 1971
#
#
# ---
#
#
# 2. **Casualties**
#
# (a) Most number of casualties: 85618 in 2014
#
# (b) Least number of casualties: 255 in 1971
#
#
# ---
#
#
#
# 3.  **Killed**
#
# (a) Most number of people killed: 44490 in 2014
#
# (b) Least number of people killed: 173 in 1971
#
#
# ---
#
#
# 4. **Wounded**
#
# (a) Most number of people wounded: 44043 in 2015
#
# (b) Least number of people wounded: 82 in 1971
#
#
# ---

# %% [markdown]
# # **Country wise Attacks [Top 50]**

# %%
ct=df["Country"].value_counts().head(50)
ct
# Out:
# Iraq                                24636
# Pakistan                            14368
# Afghanistan                         12731
# India                               11960
# Colombia                             8306
# Philippines                          6908
# Peru                                 6096
# El Salvador                          5320
# United Kingdom                       5235
# Turkey                               4292
# Somalia                              4142
# Nigeria                              3907
# Thailand                             3849
# Yemen                                3347
# Spain                                3249
# Sri Lanka                            3022
# United States                        2836
# Algeria                              2743
# France                               2693
# Egypt                                2479
# Lebanon                              2478
# Chile                                2365
# ...

# %%
ct.plot(kind="bar",color="blue",figsize=(12,5))
plt.title("Country wise Attacks",fontsize=13)
plt.xlabel("Countries",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %%
cnc=df[["Country","Casualty"]].groupby("Country").sum().sort_values(by="Casualty",ascending=False)
cnc.head(50)
# Out:
#                                   Casualty
# Country
# Iraq                              213279.0
# Afghanistan                        83661.0
# Pakistan                           65860.0
# India                              48321.0
# Nigeria                            32921.0
# Sri Lanka                          31091.0
# Syria                              29338.0
# Colombia                           25026.0
# United States                      24473.0
# Philippines                        22926.0
# Algeria                            20216.0
# Somalia                            19148.0
# Yemen                              18104.0
# El Salvador                        17115.0
# Peru                               16849.0
# Turkey                             16787.0
# Lebanon                            14965.0
# Nicaragua                          12329.0
# Russia                             11749.0
# Thailand                           10560.0
# Israel                              9649.0
# ...

# %%
cnc[:50].plot(kind="bar",color="blue",figsize=(15,6))
plt.title("Country wie Casualties",fontsize=13)
plt.xlabel("Countries",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %%
cnk=df[["Country","Killed"]].groupby("Country").sum().sort_values(by="Killed",ascending=False)
cnk.head(50)
# Out:
#                                    Killed
# Country
# Iraq                              78589.0
# Afghanistan                       39384.0
# Pakistan                          23822.0
# Nigeria                           22682.0
# India                             19341.0
# Sri Lanka                         15530.0
# Syria                             15229.0
# Colombia                          14698.0
# Peru                              12771.0
# El Salvador                       12053.0
# Algeria                           11066.0
# Nicaragua                         10598.0
# Somalia                           10273.0
# Philippines                        9559.0
# Yemen                              8776.0
# Turkey                             6888.0
# Guatemala                          5167.0
# Russia                             4308.0
# Burundi                            4205.0
# Democratic Republic of the Congo   4069.0
# Lebanon                            4061.0
# ...

# %%
cnw=df[["Country","Wounded"]].groupby("Country").sum().sort_values(by="Wounded",ascending=False)
cnw.head(50)
# Out:
#                                    Wounded
# Country
# Iraq                              134690.0
# Afghanistan                        44277.0
# Pakistan                           42038.0
# India                              28980.0
# United States                      20702.0
# Sri Lanka                          15561.0
# Syria                              14109.0
# Philippines                        13367.0
# Lebanon                            10904.0
# Colombia                           10328.0
# Nigeria                            10239.0
# Turkey                              9899.0
# Yemen                               9328.0
# Algeria                             9150.0
# Somalia                             8875.0
# Bangladesh                          8225.0
# Israel                              7946.0
# Thailand                            7818.0
# Russia                              7441.0
# Japan                               6998.0
# Kenya                               6263.0
# ...

# %%
cnw=df[["Country","Wounded"]].groupby("Country").sum().sort_values(by="Wounded",ascending=False)
cnw.head(50)
# Out:
#                                    Wounded
# Country
# Iraq                              134690.0
# Afghanistan                        44277.0
# Pakistan                           42038.0
# India                              28980.0
# United States                      20702.0
# Sri Lanka                          15561.0
# Syria                              14109.0
# Philippines                        13367.0
# Lebanon                            10904.0
# Colombia                           10328.0
# Nigeria                            10239.0
# Turkey                              9899.0
# Yemen                               9328.0
# Algeria                             9150.0
# Somalia                             8875.0
# Bangladesh                          8225.0
# Israel                              7946.0
# Thailand                            7818.0
# Russia                              7441.0
# Japan                               6998.0
# Kenya                               6263.0
# ...

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
cnk[:50].plot(kind="bar",color="blue",figsize=(20,6),ax=ax0)
ax0.set_title("People Killed in each Country")
ax0.set_xlabel("Countries")
ax0.set_ylabel("Number of People Killed")

#Wounded
cnw[:50].plot(kind="bar",color="blue",figsize=(20,6),ax=ax1)
ax1.set_title("People Wounded in each Country")
ax1.set_xlabel("Countries")
ax1.set_ylabel("Number of People Wounded")

plt.show()

# %% [markdown]
# 2. Country wise Attacks [Top 50] :
#
# (i) **Attacks**
#
# (a) Most number of attacks: 24636 in "Iraq"
#
# (b) Least number of attacks: 394 in "Uganda"
#
#
#
# ---
#
#
#   (ii) **Casualties**
#
#
# (a) Most number of casualties: 213279 in "Iraq"
#
#
# (b) Least number of casualties: 2800 in "Chad"
#
#
# ---
#
#
#
#   (iii) **Killed**
#
#
# (a) Most number of people killed: 78589 in "Iraq"
#
#
# (b) Least number of people killed: 1008 in "China"
#
#
#
# ---
#
#
#
#   (iv) **Wounded**
#
# (a) Most number of people wounded: 134690 in "Iraq"
#
#
# (b) Least number of people wounded: 1145 in "Uganda"
#
#
# ---

# %% [markdown]
# # **Terrorist Group wise Attacks [Top 50]**

# %%
grp=df["Group Name"].value_counts()[1:50]
grp
# Out:
# Taliban                                                        7478
# Islamic State of Iraq and the Levant (ISIL)                    5613
# Shining Path (SL)                                              4555
# Farabundo Marti National Liberation Front (FMLN)               3351
# Al-Shabaab                                                     3288
# New People's Army (NPA)                                        2772
# Irish Republican Army (IRA)                                    2671
# Revolutionary Armed Forces of Colombia (FARC)                  2487
# Boko Haram                                                     2418
# Kurdistan Workers' Party (PKK)                                 2310
# Basque Fatherland and Freedom (ETA)                            2024
# Communist Party of India - Maoist (CPI-Maoist)                 1878
# Maoists                                                        1630
# Liberation Tigers of Tamil Eelam (LTTE)                        1606
# ...

# %%
grp.plot(kind="bar",color="black",figsize=(20,5))
plt.title("Group wise Attacks",fontsize=13)
plt.xlabel("Terrorist Groups",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %%
gc=df[["Group Name","Casualty"]].groupby("Group Name").sum().sort_values(by="Casualty",ascending=False).drop("Unknown")
gc.head(50)
# Out:
#                                                     Casualty
# Group Name
# Islamic State of Iraq and the Levant (ISIL)          69595.0
# Taliban                                              57342.0
# Boko Haram                                           29801.0
# Al-Qaida                                             28372.0
# Liberation Tigers of Tamil Eelam (LTTE)              22020.0
# Al-Shabaab                                           16954.0
# Tehrik-i-Taliban Pakistan (TTP)                      15574.0
# Al-Qaida in Iraq                                     14724.0
# Shining Path (SL)                                    14632.0
# Farabundo Marti National Liberation Front (FMLN)     12130.0
# Revolutionary Armed Forces of Colombia (FARC)        10015.0
# Kurdistan Workers' Party (PKK)                        9863.0
# New People's Army (NPA)                               7719.0
# Nicaraguan Democratic Force (FDN)                     7396.0
# ...

# %%
gc.head(50).plot(kind="bar",color="black",figsize=(15,5))
plt.title("Casualties by each Group",fontsize=13)
plt.xlabel("Terrorist Groups",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %%
gk=df[["Group Name","Killed"]].groupby("Group Name").sum().sort_values(by="Killed",ascending=False).drop("Unknown")
gk.head(50)
# Out:
#                                                      Killed
# Group Name
# Islamic State of Iraq and the Levant (ISIL)         38923.0
# Taliban                                             29410.0
# Boko Haram                                          20328.0
# Shining Path (SL)                                   11601.0
# Liberation Tigers of Tamil Eelam (LTTE)             10989.0
# Al-Shabaab                                           9330.0
# Farabundo Marti National Liberation Front (FMLN)     8065.0
# Nicaraguan Democratic Force (FDN)                    6662.0
# Tehrik-i-Taliban Pakistan (TTP)                      6042.0
# Revolutionary Armed Forces of Colombia (FARC)        5661.0
# Kurdistan Workers' Party (PKK)                       4955.0
# New People's Army (NPA)                              4386.0
# Al-Qaida in Iraq                                     4381.0
# Hutu extremists                                      4102.0
# ...

# %%
gw=df[["Group Name","Wounded"]].groupby("Group Name").sum().sort_values(by="Wounded",ascending=False).drop("Unknown")
gw.head(50)
# Out:
#                                                     Wounded
# Group Name
# Islamic State of Iraq and the Levant (ISIL)         30672.0
# Taliban                                             27932.0
# Al-Qaida                                            24512.0
# Liberation Tigers of Tamil Eelam (LTTE)             11031.0
# Al-Qaida in Iraq                                    10343.0
# Tehrik-i-Taliban Pakistan (TTP)                      9532.0
# Boko Haram                                           9473.0
# Al-Shabaab                                           7624.0
# Aum Shinri Kyo                                       6003.0
# Kurdistan Workers' Party (PKK)                       4908.0
# Islamic State of Iraq (ISI)                          4489.0
# Revolutionary Armed Forces of Colombia (FARC)        4354.0
# Farabundo Marti National Liberation Front (FMLN)     4065.0
# Irish Republican Army (IRA)                          3658.0
# ...

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
gk[:50].plot(kind="bar",color="black",figsize=(20,6),ax=ax0)
ax0.set_title("People Killed by each Group")
ax0.set_xlabel("Terrorist Groups")
ax0.set_ylabel("Number of people Killed")

#Wounded
gw[:50].plot(kind="bar",color="black",figsize=(20,6),ax=ax1)
ax1.set_title("People Wounded by each Group")
ax1.set_xlabel("Terrorist Groups")
ax1.set_ylabel("Number of people Wounded")
plt.show()

# %% [markdown]
# 3. Terrorist Group wise Attacks [Top 10] :
#
#   (i) Attacks
#
#
# (a) Most number of attacks : 7478 by "Taliban"
#
#
# (b) Least number of attacks : 322 by "Boko Lord's Resistance Army (LRA)"
#
#
#
# ---
#
#
#
#   (ii) Casualties
#
#
# (a) Most number of casualties : 69595 by "Islamic State of Iraq and the Levant (ISIL)"
#
#
#  (b) Least number of casualties : 2144.0  by " Islamist extremists"
#
#
#
# ---
#
#
#   (iii) Killed
#
#
# (a) Most number of people killed : 38923 by "Islamic State of Iraq and the Levant (ISIL)"
#
#
#  (b) Least number of people killed :813.0 by "Death Squad"
#
#
#
# ---
#
#
#   (iv) Wounded
#
#
# (a) Most number of people wounded : 30672 by "Islamic State of Iraq and the Levant (ISIL)"
#
#
# (b) Least number of people wounded : 1016.0 by "Muslim Militants"
#
#
#
# ---

# %% [markdown]
# # **Group and Country wise Attacks [Top 50]**

# %%
gca=df[["Group Name","Country"]].value_counts().drop("Unknown")
gca.head(50)
# Out:
# <ipython-input-115-1634a989a93a>:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   gca=df[["Group Name","Country"]].value_counts().drop("Unknown")
# Group Name                                                   Country
# Taliban                                                      Afghanistan                 7423
# Islamic State of Iraq and the Levant (ISIL)                  Iraq                        4797
# Shining Path (SL)                                            Peru                        4541
# Farabundo Marti National Liberation Front (FMLN)             El Salvador                 3330
# Al-Shabaab                                                   Somalia                     2867
# New People's Army (NPA)                                      Philippines                 2770
# Irish Republican Army (IRA)                                  United Kingdom              2575
# ...

# %%
gca.head(50).plot(kind="bar",color="green",figsize=(20,3))
plt.title("Countries with most attacks by a particular Group",fontsize=14)
plt.xlabel("(Terrorist Group,Country)",fontsize=14)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=14)
plt.show()

# %%
gcc=df[["Group Name","Country","Casualty"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Casualty",ascending=False).drop("Unknown").head(50)
gcc
# Out:
# <ipython-input-117-a6954dd4b0fb>:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   gcc=df[["Group Name","Country","Casualty"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Casualty",ascending=False).drop("Unknown").head(50)
#                                                                    Casualty
# Group Name                                         Country
# Taliban                                            Afghanistan      57140.0
# Islamic State of Iraq and the Levant (ISIL)        Iraq             54755.0
# Boko Haram                                         Nigeria          24588.0
# Liberation Tigers of Tamil Eelam (LTTE)            Sri Lanka        21919.0
# Al-Qaida                                           United States    19494.0
# Tehrik-i-Taliban Pakistan (TTP)                    Pakistan         15532.0
# Shining Path (SL)                                  Peru             14625.0
# ...

# %%
gcc.plot(kind="bar",color="green",figsize=(15,6))
plt.title("Countries with most casualties by a particular Group",fontsize=13)
plt.xlabel("(Terrorist Group,Country)",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %%
gck=df[["Group Name","Country","Killed"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Killed",ascending=False).drop("Unknown").head(50)
gck
# Out:
# <ipython-input-119-e95e9e0540bd>:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   gck=df[["Group Name","Country","Killed"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Killed",ascending=False).drop("Unknown").head(50)
#                                                                                       Killed
# Group Name                                         Country
# Islamic State of Iraq and the Levant (ISIL)        Iraq                              31058.0
# Taliban                                            Afghanistan                       29269.0
# Boko Haram                                         Nigeria                           16917.0
# Shining Path (SL)                                  Peru                              11595.0
# Liberation Tigers of Tamil Eelam (LTTE)            Sri Lanka                         10928.0
# ...

# %%
gck.plot(kind="bar",color="green",figsize=(15,6))
plt.title("Countries with most people killed by a particular Group",fontsize=13)
plt.xlabel("(Terrorist Group,Country)",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of people Killed",fontsize=13)
plt.show()

# %%
gcw=df[["Group Name","Country","Wounded"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Wounded",ascending=False).drop("Unknown").head(50)
gcw
# Out:
# <ipython-input-121-70efe01887f0>:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   gcw=df[["Group Name","Country","Wounded"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Wounded",ascending=False).drop("Unknown").head(50)
#                                                                    Wounded
# Group Name                                         Country
# Taliban                                            Afghanistan     27871.0
# Islamic State of Iraq and the Levant (ISIL)        Iraq            23697.0
# Al-Qaida                                           United States   16493.0
# Liberation Tigers of Tamil Eelam (LTTE)            Sri Lanka       10991.0
# Al-Qaida in Iraq                                   Iraq            10075.0
# Tehrik-i-Taliban Pakistan (TTP)                    Pakistan         9518.0
# Boko Haram                                         Nigeria          7671.0
# ...

# %%
gcw.plot(kind="bar",color="green",figsize=(15,6))
plt.title("Countries with most people wounded by a particular Group",fontsize=13)
plt.xlabel("(Terrorist Group,Country)",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of people Wounded",fontsize=13)
plt.show()

# %% [markdown]
# 4. Group and Country wise Attacks [Top 50] :
#
#
#   (i) Attacks
#
#
# (a) Most number of attacks : 7423 by "Taliban" in "Afghanistan"
#
#
#  (b) Least number of attacks : 291 by "Mozambique National Resistance Movement(MNR)" in "Mozambique"
#
#
# ---
# (ii) Casualties
#
#
# (a) Most number of casualties : 57140 by "Taliban" in "Afghanistan"
#
#
# (b) Least number of casualties : 1917 by "Hutu extremists" in "Burundi"
#
#
# ---
#
#
#
#   (iii) Killed
#
#
# (a) Most number of people killed : 31058 by "Islamic State of Iraq and the Levant (ISIL)" in "Iraq"
#
#
# (b) Least number of people killed : 814 by "Basque Fatherland and Freedom " in "Spain"
#
#
#
# ---
#
#
#   (iv) Wounded
#
#
#  (a) Most number of people wounded : 27871 by "Taliban" in "Afghanistan"
#
#
# (b) Least number of people wounded : 1001 by "Rebels" in "Chad"
#
#
# ---

# %% [markdown]
# # **Humanity Affected (World-wide) by Terrorist Attacks from 1970 to 2017**

# %%
casualty=df.loc[:,"Casualty"].sum()
print("Total number of Casualties due to Terrorist Attacks from 1970 to 2017 across the world :\n",casualty)
# Out:
# Total number of Casualties due to Terrorist Attacks from 1970 to 2017 across the world :
#  935737.0

# %%
kill=df.loc[:,"Killed"].sum()
print("Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :\n",kill)
# Out:
# Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :
#  411868.0

# %%
wound=df.loc[:,"Wounded"].sum()
print("Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :\n",wound)
# Out:
# Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :
#  523869.0

# %% [markdown]
# **5. Humanity Affected (World-wide) by Terrorist Attacks from 1970 to 2017 :**
#
#
#   (i) Total number of Casualties due to Terrorist Attacks from 1970 to 2017 across the world : 935737
#
#
#   (ii) Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world : 411868
#
#
#   (iii) Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world : 523869

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The majority of the attacks were carried out with explosives first, followed by weapons. Attacks increased in 2014 and then decreased in 2015. The previous six years had the highest number of assaults since 1970. However, beginning in 2014, the count began to decline. Almost every day contributes the same amount, however attacks were low on the 31st and high on the 15th and 1st.
# Iraq tops all nations and has the most number of attacks, followed by Pakistan, Afghanistan, and India.The Middle East and North Africa are first among all regions, with South Asia coming in second.
# The majority of the attacks target private citizens and their property, with the military following close behind.
# The majority of the attacks were either bombings or explosions.

# %% [markdown]
# Terrorism Reduction Measures to be Implemented
# Governments should offer better protection over countries by limiting access to hazardous weapons.
# Cross-border security should be improved.
# The government should take steps to promote immigration, among other things...
